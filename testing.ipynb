# %%
import pandas as pd

# Create a DataFrame with the dummy data
data = {
    "First Name": ["Anirudh", "Anirudh", "Anirudh", "Anirudh", "Anirudh", "Anirudh", "Anirudh", "Anirudh", "Anirudh", "Anirudh"],
    "Last Name": ["Iyengar", "Iyengar", "Kaniyar", "Narayana", "Iyengar", "Kaniyar", "Iyengar", "Narayana", "Kaniyar", "Iyengar"],
    "Email": ["anirudh.iyengar@example.com", "anirudh.iyengar2@example.com", "anirudh.kaniyar@example.com", "anirudh.narayana@example.com", 
              "anirudh.iyengar3@example.com", "anirudh.kaniyar2@example.com", "anirudh.iyengar4@example.com", "anirudh.narayana2@example.com", 
              "anirudh.kaniyar3@example.com", "anirudh.iyengar5@example.com"],
    "Company Name": ["TechCorp", "DataWorks", "AI Solutions", "VisionTech", "HealthTech", "RoboTech", "DeepMind", "InnovateAI", "FutureLabs", "RoboLab"],
    "Designation": ["Software Engineer", "Data Scientist", "AI Researcher", "Computer Vision Engineer", "Machine Learning Engineer", "Robotics Engineer", 
                    "AI Engineer", "AI Researcher", "Software Engineer", "Data Engineer"],
    "Position": ["Machine Learning Engineer", "Data Scientist", "Research Scientist", "Computer Vision Engineer", "Data Scientist", "Machine Learning Engineer",
                 "AI Engineer", "Data Scientist", "Research Scientist", "Machine Learning Engineer"]
}

# Create a pandas DataFrame
df = pd.DataFrame(data)

# Write the DataFrame to a CSV file
df.to_csv('dummy_data.csv', index=False)

print("CSV file 'dummy_data.csv' created successfully.")
# Out:
# CSV file 'dummy_data.csv' created successfully.
